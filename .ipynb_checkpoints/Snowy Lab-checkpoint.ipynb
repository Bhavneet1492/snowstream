# %%
# !pip show snowflake-snowpark-python
# Out:
# Name: snowflake-snowpark-python
# Version: 1.3.0
# Summary: Snowflake Snowpark for Python
# Home-page: https://www.snowflake.com/
# Author: Snowflake, Inc
# Author-email: snowflake-python-libraries-dl@snowflake.com
# License: Apache License, Version 2.0
# Location: c:\users\hardeep singh khalsa\new folder (2)\envs\py38_env\lib\site-packages
# Requires: cloudpickle, setuptools, snowflake-connector-python, typing-extensions, wheel
# Required-by:

# %%
# !pip install snowflake
# Out:
# ...
#   Using cached snowflake-0.0.3-py3-none-any.whl
# ...

# %%
from snowflake import connector

# %%
import snowflake.snowpark
import snowflake.snowpark.functions
import snowflake.snowpark.types

# %%
from snowflake.snowpark import Session

# %%
import snowflake.snowpark as snowpark
from snowflake.snowpark.functions import col

def main(session: snowpark.Session):
    df_table = session.table("sample_product_data")
    print(df_table)
    return df_table
print(main)
# Out:
# <function main at 0x00000203C2E73AF0>

# %% [markdown]
# # Initialize Notebook, import libraries and create Snowflake connection

# %%
from snowflake.snowpark.session import Session
from snowflake.snowpark.types import IntegerType, FloatType
from snowflake.snowpark.functions import avg, sum, col, udf, call_udf, call_builtin, year
import pandas as pd
from datetime import date
# Out:
# C:\Users\hardeep singh khalsa\New folder (2)\envs\py38_env\lib\site-packages\snowflake\connector\options.py:107: UserWarning: You have an incompatible version of 'pyarrow' installed (11.0.0), please install a version that adheres to: 'pyarrow<10.1.0,>=10.0.1; extra == "pandas"'
#   warn_incompatible_dep(
# Failed to import ArrowResult. No Apache Arrow result set format can be used. ImportError: DLL load failed while importing arrow_iterator: The specified procedure could not be found.

# %%
# scikit-learn
from sklearn.linear_model import LinearRegression

# %%
# Session
connection_parameters = {
   "account": "wxdxbvk-ci09735",
   "user": "GLITCHFILTER",
   "password": "Icecream@1234",
   "warehouse": "compute_wh",
   "role": "accountadmin",
   "database": "openalex",
   "schema": "public"
}
session = Session.builder.configs(connection_parameters).create()

# test if we have a connection
session.sql("select current_warehouse() wh, current_database() db, current_schema() schema, current_version() v").show()
# Out:
# ---------------------------------------------
# |"WH"        |"DB"      |"SCHEMA"  |"V"     |
# ---------------------------------------------
# |COMPUTE_WH  |OPENALEX  |NULL      |7.12.3  |
# ---------------------------------------------

# %% [markdown]
# # Query Data

# %%
session.sql("select * from openalex.works where contains(concepts,'C71924100') limit 100").show()
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# Now use Snowpark dataframe
snow_df_pce = (session.table("openalex.works").filter(col('DOI') == 'https://doi.org/10.1007/978-3-642-20320-6_63'))
snow_df_pce.show()
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
pd.DataFrame(session.sql("select * from openalex.works where contains(concepts,'C71924100') limit 100").collect())
# Out:
#     OPENALEX_ID                                ID  \
# 0   W2246095192  https://openalex.org/W2246095192
# 1   W2246491696  https://openalex.org/W2246491696
# 2   W2246347580  https://openalex.org/W2246347580
# 3   W2246779356  https://openalex.org/W2246779356
# 4   W2246930255  https://openalex.org/W2246930255
# ..          ...                               ...
# 95  W2246733228  https://openalex.org/W2246733228
# 96  W2246308503  https://openalex.org/W2246308503
# 97  W2742387571  https://openalex.org/W2742387571
# 98  W2742254618  https://openalex.org/W2742254618
# 99  W2742831092  https://openalex.org/W2742831092
#
#                                                   DOI  \
# 0                                                None
# 1   https://doi.org/10.1200/jco.2006.24.18_suppl.1...
# 2                                                None
# 3                                                None
# 4                                                None
# ...

# %%
"# list("Moustafa Mnk")
'|'.join("Moustafa Mnk")"
# Out:
# 'M|o|u|s|t|a|f|a| |M|n|k'

# %%
session.sql("select * from openalex.works where contains(concepts,'C71924100') limit 100")
